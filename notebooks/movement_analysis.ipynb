# %%
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
def extract_positions_from_log(file_path, field):
    positions = []

    # Regex to match the [POS] line and extract x, y, z as floats
    pattern = re.compile(rf"\[{field}\]\[([-\d.eE]+)d,([-\d.eE]+)d,([-\d.eE]+)d\]")

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            match = pattern.search(line)
            if match:
                x, y, z = map(float, match.groups())
                positions.append((x, y, z))
    return np.array(positions)

# %%
positions = extract_positions_from_log("../data/movements/sprint_jump_accel.log", "xyz")[3:]
velocities = extract_positions_from_log("../data/movements/sprint_jump_accel.log", "vel")[3:]
y = positions[:, 1]

diffs = np.diff(positions, axis=0)

vy = diffs[:, 1]
vh = np.linalg.norm(diffs[:, [0, 2]], axis=1)

vvy = velocities[:, 1]
vvh = np.linalg.norm(velocities[:, [0, 2]], axis=1)

print(vvy)

print(np.mean(vh), np.mean(vvh))
# Out:
# [-0.0784     -0.0784     -0.0784     -0.0784      0.41999999  0.33319999
#   0.248136    0.16477328  0.08307782  0.00301626 -0.07544407 -0.15233519
#  -0.22768849 -0.30153472 -0.37390404 -0.0784      0.41999999  0.33319999
#   0.248136    0.16477328  0.08307782  0.00301626 -0.07544407 -0.15233519
#  -0.22768849 -0.30153472 -0.37390404 -0.0784      0.41999999  0.33319999
#   0.248136    0.16477328  0.08307782  0.00301626 -0.07544407 -0.15233519
#  -0.22768849 -0.30153472 -0.37390404 -0.0784      0.41999999  0.33319999
#   0.248136    0.16477328  0.08307782  0.00301626 -0.07544407]
# 0.3225369722842235 0.13798817961264098

# %%
plt.plot(np.arange(len(vh)), vh, label="vh")
plt.legend()

# %%
plt.plot(np.arange(len(vy)), vy, label="vy")
plt.legend()

# %%
plt.plot(np.arange(len(vvh)), vvh, label="vvh")
plt.legend()

# %%
plt.plot(np.arange(len(vvy)), vvy, label="vvy")
plt.plot(np.arange(len(vy)), vy, label="vy")

plt.legend()
print(np.mean(vvy))
# Out:
# 0.02110318693618414

# %%
# simulate sprint jumping 


g_ground = 0.0784
g_up = 0.0828
g_down = 0.075

jump_strength = 0.415 + g_up

sprint_speed = 0.28

base_jump_boost = 0.24
jump_boost_rel = 0.32
air_fric_rel = 0.14
jump_boost = 0.2
air_fric = 0.3
air_fric_ground = 1.5
air_fric_ground_rel = 5

walk_accel = 0.0971
sprint_accel = 0.0971 * 1.3
walk_air_accel = 0.0197
sprint_air_accel = walk_air_accel * 1.3

sim_y = y[0] + 60
sim_vy = vvy[0]
sim_vx = vh[0]
sim_vvx = vvh[0]

ys = [sim_y]
vys = [sim_vy]
vxs = [sim_vx]
vvxs = [sim_vvx]

for t in range(1, len(vvy)):
    
    if sim_y > 0:
        sim_vx -= air_fric * (np.abs(sim_vx)) * 0.3
        sim_vvx -= air_fric * (np.abs(sim_vvx)) * 0.3
    else:
        sim_vx -= air_fric_ground * (np.abs(sim_vx)) * 0.3
        sim_vvx -= air_fric_ground * (np.abs(sim_vvx)) * 0.3
        
    if vvy[t] > 0.4: # one frame after jump input
        sim_vy = jump_strength
        sim_vvx += jump_boost
    if t + 1 < len(vvy) and vvy[t+1] > 0.4:
        sim_vx += jump_boost

    if sim_vy > 0:
        g = g_up
    else:
        g = g_down
        
        
    sim_vy -= g
    
    sim_y = np.maximum(sim_y + sim_vy, 0)
    
    #if t > 1 and t + 1 < len(vvy) and  vvy[t+1] > 0.4:   
    #    sim_vx += jump_boost_rel
    
    if sim_y == 0 and vvy[t] < 0.4:
        sim_vy = -g_down
        
    if sim_y == 0:
        sim_vx += sprint_accel
    else:
        sim_vx += sprint_air_accel
        
    

    
    ys.append(sim_y)
    vys.append(sim_vy)
    
    vxs.append(sim_vx)
    vvxs.append(sim_vvx)

# %%
plt.plot(np.arange(len(vvy)), vvy, label="vvy")
plt.plot(np.arange(len(vys)), vys, label="sim_vvy")
plt.plot(np.arange(len(y)), y+60, label="y")
plt.plot(np.arange(len(ys)), ys, label="sim_y")
#plt.hlines(-g_ground, 0, 37)
plt.grid()

plt.legend()

# %%
plt.plot(np.arange(len(vvh)), vvh, label="vvh", linestyle=":")
plt.plot(np.arange(len(vvxs)), vvxs, label="sim_vvx", linestyle="--")
plt.plot(np.arange(len(vh)), vh, label="vh", linestyle=":")
plt.plot(np.arange(len(vxs)), vxs, label="sim_vx", linestyle="--")

plt.grid()

plt.legend()
